# %% [markdown]
# # Práticas Computacionais Avançadas - NLP
#
# ## Extração de dados para análise do uso de compostos químicos na síntese de perovskitas

# %%
# ---------------------------------------------------------------------------- #
#                                     SETUP                                    #
# ---------------------------------------------------------------------------- #

# -------------------------------- Importações ------------------------------- #
import nltk
import pandas as pd

# ------------------------ Carregando dados coletados ------------------------ #
data = pd.read_excel("prvsk_data/1_to_1000.xls")
# --------------!!!!!!!! COLOCAR O RESTO DOS DADOS DEPOIS !!!!!!!!--------------
corpora = [abstract for abstract in data["Abstract"]]
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.26.0
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
# ---------------------------------------------------------------------------- #
#                           PRÉ-PROCESSAMENTO (NLTK)                           #
# ---------------------------------------------------------------------------- #

# ------------------ "Tokenização" dos corpus obtidos (NLTK) ----------------- #
tokens = []

for corpus in corpora:
    doc = nltk.tokenize.word_tokenize(corpus)
    tokens.extend(doc)

# ------------------ Removendo stop-words e pontuação (NLTK) ----------------- #
stop_words = set(nltk.corpus.stopwords.words('english'))
print(f'Stop words: {stop_words}')
print()

tokens = [token for token in tokens if (not token in stop_words and token.isalnum())]

print(tokens)
# Out:
# Stop words: {'above', 'myself', 'that', 'just', 'an', 'he', 'over', 'hers', 'her', 'out', 'about', 'couldn', 'or', 'to', 'been', 're', 'what', 'will', "you're", 'are', 'nor', "won't", 'so', 'should', "it's", "hadn't", 'not', "didn't", 'be', 'then', 'some', 'have', 'on', 'after', 'up', 'because', 'the', 'himself', 'll', 'which', 'it', 'ourselves', 'they', 've', 'y', 'theirs', 'few', "aren't", 'too', 'through', "weren't", 'had', 'where', 'if', 'ain', 'd', 'those', 'am', 'isn', 'i', 'during', 'is', 'me', 'no', "doesn't", 'than', "you'd", 'same', 'them', 'yourself', 'of', 'once', 'both', 'doing', 'needn', "that'll", 'again', 'o', 'and', 'when', 'whom', 'being', "couldn't", 'for', 'itself', 'with', 'any', 'has', 'do', 'won', 'its', 'this', 'between', 'further', "you've", 'in', "wasn't", 'very', 'such', 'each', 'until', 'hadn', 'shan', "shan't", 'herself', 'ours', "don't", "should've", 'how', 'into', 'him', 'now', 'aren', "mustn't", 'off', 'under', 'only', "shouldn't", 'your', 'why', 'we', 'below', "you'll", "she's", 'here', 'by', 'all', 'haven', "mightn't", 'does', "wouldn't", 'you', 'their', 'more', 'at', 'down', 'my', 'did', 'don', 'hasn', 'his', 'there', 'yours', 'before', 'was', 'ma', 'as', 'wouldn', 'from', "needn't", 'm', 'weren', 'but', 'shouldn', 'these', "hasn't", 'while', 'were', 'our', 'mustn', 'most', 'themselves', 'can', 'wasn', 'own', 'doesn', 's', 'she', 'who', 'yourselves', 'mightn', 'other', "haven't", 'having', 'didn', 'a', 'against', "isn't", 't'}
#
# ['CsPbX3', 'perovskite', 'material', 'benefits', 'advanced', 'light', 'absorption', 'coefficient', 'long', 'carrier', 'lifetime', 'simple', 'preparation', 'process', 'perovskite', 'materials', 'also', 'maintains', 'excellent', 'stability', 'erosion', 'damp', 'heat', 'Stability', 'premise', 'industrialization', 'perovskite', 'undoubtedly', 'competitive', 'direction', 'development', 'perovskite', 'materials', 'However', 'still', 'many', 'defects', 'perovskite', 'thin', 'films', 'difficult', 'obtain', 'high', 'power', 'conversion', 'efficiency', 'PCE', 'This', 'review', 'systematically', 'summarizes', 'additive', 'engineering', 'solvent', 'engineering', 'interface', 'engineering', 'methods', 'promote', 'thin', 'film', 'property', 'high', 'PCE', 'recent', 'years', 'The', 'photovoltaic', 'performance', 'poly', 'P3HT', 'perovskite', 'solar', 'cells', 'inferior', 'due', 'improper', 'interface', 'caused', 'surface', 'energy', 'mismatch', 'The', 'promising', 'method', 'improve', 'interface', 'introduction', 'interlayers', 'perovskite', 'P3HT', 'layers', 'however', 'increases', 'fabrication', 'complexity', 'irreproducibility', 'Here', 'show', 'surface', 'topography', 'perovskite', 'layer', 'improve', 'interface', 'without', 'interlayer', 'To', 'explore', 'varied', 'surface', 'topography', 'altering', 'crystal', 'size', 'methylammonium', 'lead', 'iodide', 'deposition', 'temperature', 'namely', '10', '0C', '30', '0C', 'The', 'solar', 'cells', 'based', 'perovskite', 'layers', 'formed', '10', '0C', 'outperform', 'cells', 'fabricated', 'perovskite', 'layers', 'deposited', '30', '0C', 'Our', 'studies', 'reveal', 'surface', 'topography', 'perovskite', 'layer', 'influences', 'surface', 'energy', 'impacts', 'interface', 'perovskite', 'P3HT', 'layers', 'consequently', 'enhancing', 'recombination', 'resistance', 'current', 'voltage', 'ultimately', 'improving', 'photovoltaic', 'performance', 'Modification', 'surface', 'topography', 'simple', 'approach', 'improve', 'P3HT', 'interface', 'without', 'interlayer', 'lead', 'better', 'performance', 'perovskite', 'solar', 'cells', 'detection', 'widespread', 'applications', 'medical', 'diagnosis', 'industrial', 'radiography', 'safety', 'inspection', 'especially', 'medical', 'diagnosis', 'realized', 'medical', 'detectors', 'presenting', 'increasing', 'demand', 'Perovskite', 'materials', 'excellent', 'candidates', 'radiation', 'detection', 'based', 'promising', 'material', 'properties', 'excellent', 'carrier', 'transport', 'capability', 'high', 'effective', 'atomic', 'number', 'In', 'review', 'paper', 'introduce', 'detectors', 'using', 'kinds', 'halide', 'perovskite', 'materials', 'along', 'various', 'crystal', 'structures', 'discuss', 'device', 'performance', 'detail', 'perovskite', 'first', 'fabricated', 'active', 'material', 'detectors', 'excellent', 'performance', 'illumination', 'due', 'superior', 'photoelectric', 'properties', 'attenuation', 'mu', 'thickness', 'The', 'detector', 'based', 'inorganic', 'perovskite', 'shows', 'good', 'environmental', 'stability', 'high', 'sensitivity', 'Owing', 'anisotropic', 'carrier', 'transport', 'capability', 'layered', 'perovskites', 'preferred', 'orientation', 'parallel', 'substrate', 'effectively', 'suppress', 'dark', 'current', 'device', 'despite', 'poor', 'light', 'response', 'resulting', 'lower', 'sensitivity', 'device', 'Double', 'perovskite', 'applied', 'detectors', 'shows', 'better', 'attenuation', 'due', 'introduction', 'elements', 'Additionally', 'stable', 'crystal', 'structure', 'effectively', 'lower', 'dark', 'current', 'detectors', 'Environmentally', 'friendly', 'perovskite', 'exhibits', 'potential', 'application', 'detectors', 'virtue', 'high', 'attenuation', 'In', 'last', 'section', 'specifically', 'introduce', 'process', 'technology', 'fabricating', 'thick', 'perovskite', 'films', 'detectors', 'critical', 'commercialization', 'mass', 'production', 'detectors', 'Inorganic', 'CsPbIBr2', 'perovskite', 'considered', 'promising', 'material', 'solar', 'cells ...

# %%
# ---------------- EXTRA: Classificação Morfossintática (NLTK) --------------- #
extra = corpora[0]
doc = nltk.tokenize.sent_tokenize(extra)
sent = nltk.tokenize.word_tokenize(doc[2])

pos_tags = nltk.pos_tag(sent)
for tag in pos_tags: print(tag)
# Out:
# ('However', 'RB')
# (',', ',')
# ('there', 'EX')
# ('are', 'VBP')
# ('still', 'RB')
# ('many', 'JJ')
# ('defects', 'NNS')
# ('in', 'IN')
# ('the', 'DT')
# ('all-inorganic', 'JJ')
# ('perovskite', 'NN')
# ('thin', 'JJ')
# ('films', 'NNS')
# (',', ',')
# ('and', 'CC')
# ('it', 'PRP')
# ('is', 'VBZ')
# ('difficult', 'JJ')
# ('to', 'TO')
# ('obtain', 'VB')
# ('high', 'JJ')
# ('power', 'NN')
# ('conversion', 'NN')
# ('efficiency', 'NN')
# ('(', '(')
# ('PCE', 'NNP')
# (')', ')')
# ('.', '.')

# %%
# -------------- EXTRA: NER - Reconhecimento de entidade (spaCy) ------------- #
tree = nltk.ne_chunk(pos_tags)

# -------------------------- + Visualização gráfica -------------------------- #
for subtree in tree:
    if isinstance(subtree, nltk.Tree):
        entity = ' '.join([word for word, tag in subtree.leaves()])
        label = subtree.label()
        print((entity, label))
# Out:
# ('PCE', 'ORGANIZATION')
